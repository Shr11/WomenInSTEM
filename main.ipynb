# %%
#Install Streamlit library

# !pip install -q streamlit

#Create a streamlit app example
# Out:
# UsageError: Line magic function `%%writefile` not found.

# %%
# %%writefile app.py

import streamlit as st

st.write('Women in STEM')
# Out:
# Writing app.py

# %%
#Install localtunnel to serve the Streamlit app

# !npm install localtunnel
# Out:
# npm WARN saveError ENOENT: no such file or directory, open '/content/package.json'
# npm WARN enoent ENOENT: no such file or directory, open '/content/package.json'
# npm WARN content No description
# npm WARN content No repository field.
# npm WARN content No README data
# npm WARN content No license field.
#
# + localtunnel@2.0.2
# updated 1 package and audited 36 packages in 0.431s
#
# 3 packages are looking for funding
#   run `npm fund` for details
#
# found 2 moderate severity vulnerabilities
#   run `npm audit fix` to fix them, or `npm audit` for details

# %%
#Run the Streamlit app in the background

# !streamlit run app.py &>/content/logs.txt &

# %%
#Expose the Streamlit app on port 8501
#Then just click in the url showed.

# !npx localtunnel --port 8501
# Out:
# npx: installed 22 in 2.095s
# your url is: https://afraid-numbers-doubt.loca.lt
# ^C

# %%
#Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(12,6))
import seaborn as sns
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)

# %% [markdown]
# Adding following code to mitigate google drive mount error:

# %%
# !sudo add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !sudo apt-get update -qq 2>&1 > /dev/null
# !sudo apt -y install -qq google-drive-ocamlfuse 2>&1 > /dev/null
# !google-drive-ocamlfuse
# Out:
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# /usr/bin/xdg-open: 882: www-browser: not found
# /usr/bin/xdg-open: 882: links2: not found
# /usr/bin/xdg-open: 882: elinks: not found
# /usr/bin/xdg-open: 882: links: not found
# /usr/bin/xdg-open: 882: lynx: not found
# /usr/bin/xdg-open: 882: w3m: not found
# xdg-open: no method available for opening 'https://accounts.google.com/o/oauth2/auth?client_id=564921029129.apps.googleusercontent.com&redirect_uri=https%3A%2F%2Fgd-ocaml-auth.appspot.com%2Foauth2callback&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force&state=CzVdodf0ERLturqG%2FerbKIQ7cfhMpqPn7A4X3jOev5w'
# /bin/sh: 1: firefox: not found
# /bin/sh: 1: google-chrome: not found
# /bin/sh: 1: chromium-browser: not found
# /usr/bin/open: 882: www-browser: not found
# /usr/bin/open: 882: links2: not found
# /usr/bin/open: 882: elinks: not found
# /usr/bin/open: 882: links: not found
# /usr/bin/open: 882: lynx: not found
# /usr/bin/open: 882: w3m: not found
# xdg-open: no method available for opening 'https://accounts.google.com/o/oauth2/auth?client_id=564921029129.apps.googleusercontent.com&redirect_uri=https%3A%2F%2Fgd-ocaml-auth.appspot.com%2Foauth2callback&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force&state=CzVdodf0ERLturqG%2FerbKIQ7cfhMpqPn7A4X3jOev5w'
# Cannot retrieve auth tokens.
# Failure("Error opening URL:https://accounts.google.com/o/oauth2/auth?client_id=564921029129.apps.googleusercontent.com&redirect_uri=https%3A%2F%2Fgd-ocaml-auth.appspot.com%2Foauth2callback&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force&state=CzVdodf0ERLturqG%2FerbKIQ7cfhMpqPn7A4X3jOev5w")

# %%
# !sudo apt-get install -qq w3m # to act as web browser
# !xdg-settings set default-web-browser w3m.desktop # to set default browser
# %cd /content
# !mkdir drive
# %cd drive
# !mkdir MyDrive
# %cd ..
# %cd ..
# !google-drive-ocamlfuse /content/drive/MyDrive
# Out:
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package w3m.
# (Reading database ... 121671 files and directories currently installed.)
# Preparing to unpack .../w3m_0.5.3+git20210102-6ubuntu0.1_amd64.deb ...
# Unpacking w3m (0.5.3+git20210102-6ubuntu0.1) ...
# Setting up w3m (0.5.3+git20210102-6ubuntu0.1) ...
# Processing triggers for man-db (2.10.2-1) ...
# /content
# /content/drive
# /content
# /
# Access token retrieved correctly.

# %%
df = pd.read_csv('/content/drive/MyDrive/kaggle_survey_2022_responses.csv')

# %%
#info on data
df.info(verbose = True, null_counts = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23998 entries, 0 to 23997
# Data columns (total 296 columns):
#  #    Column                 Non-Null Count  Dtype
# ---   ------                 --------------  -----
#  0    Duration (in seconds)  23998 non-null  object
#  1    Q2                     23998 non-null  object
#  2    Q3                     23998 non-null  object
#  3    Q4                     23998 non-null  object
#  4    Q5                     23998 non-null  object
#  5    Q6_1                   9700 non-null   object
#  6    Q6_2                   2475 non-null   object
#  7    Q6_3                   6629 non-null   object
#  8    Q6_4                   3719 non-null   object
#  9    Q6_5                   945 non-null    object
#  10   Q6_6                   2200 non-null   object
#  11   Q6_7                   6117 non-null   object
#  12   Q6_8                   2767 non-null   object
#  13   Q6_9                   1822 non-null   object
#  14   Q6_10                  6781 non-null   object
#  15   Q6_11                  2644 non-null   object
#  16   Q6_12                  5670 non-null   object
#  17   Q7_1                   6852 non-null   object
#  18   Q7_2                   13715 non-null  object
#  19   Q7_3                   3311 non-null   object
#  20   Q7_4                   12872 non-null  object
#  21   Q7_5                   12701 non-null  object
#  22   Q7_6                   1023 non-null   object
#  23   Q7_7                   1945 non-null   object
#  24   Q8                     23399 non-null  object
#  25   Q9                     12362 non-null  object
#  26   Q10_1                  1550 non-null   object
#  27   Q10_2                  2464 non-null   object
#  28   Q10_3                  1914 non-null   object
#  29   Q11                    23244 non-null  object
#  30   Q12_1                  18654 non-null  object
#  31   Q12_2                  4572 non-null   object
#  32   Q12_3                  9621 non-null   object
#  33   Q12_4                  3802 non-null   object
#  34   Q12_5                  1474 non-null   object
#  35   Q12_6                  4550 non-null   object
#  36   Q12_7                  3863 non-null   object
#  37   Q12_8                  3490 non-null   object
#  38   Q12_9                  1675 non-null   object
#  39   Q12_10                 1444 non-null   object
#  40   Q12_11                 2442 non-null   object
#  41   Q12_12                 297 non-null    object
#  42   Q12_13                 323 non-null    object
#  43   Q12_14                 257 non-null    object
#  44   Q12_15                 1343 non-null   object
#  45   Q13_1                  4888 non-null   object
#  46   Q13_2                  3825 non-null   object
#  47   Q13_3                  4417 non-null   object
#  48   Q13_4                  9977 non-null   object
#  49   Q13_5                  6100 non-null   object
#  50   Q13_6                  2881 non-null   object
#  51   Q13_7                  3892 non-null   object
#  52   Q13_8                  2219 non-null   object
#  53   Q13_9                  1449 non-null   object
#  54   Q13_10                 2303 non-null   object
#  55   Q13_11                 13685 non-null  object
#  56   Q13_12                 1613 non-null   object
#  57   Q13_13                 410 non-null    object
#  58   Q13_14                 1475 non-null   object
#  59   Q14_1                  7479 non-null   object
#  60   Q14_2                  8930 non-null   object
#  61   Q14_3                  886 non-null    object
#  62   Q14_4                  159 non-null    object
#  63   Q14_5                  965 non-null    object
#  64   Q14_6                  736 non-null    object
#  65   Q14_7                  546 non-null    object
#  66   Q14_8                  261 non-null    object
#  67   Q14_9                  871 non-null    object
#  68   Q14_10                 78 non-null     object
#  69   Q14_11                 300 non-null    object
#  70   Q14_12                 611 non-null    object
#  71   Q14_13                 295 non-null    object
#  72   Q14_14                 245 non-null    object
#  73   Q14_15                 6741 non-null   object
#  74   Q14_16                 583 non-null    object
#  75   Q15_1                  14011 non-null  object
#  76   Q15_2                  10513 non-null  object
#  77   Q15_3                  5079 non-null   object
#  78   Q15_4                  4146 non-null   object
#  79   Q15_5                  1044 non-null   object
#  80   Q15_6                  735 non-null    object
#  81   Q15_7                  301 non-null    object
#  82   Q15_8                  772 non-null    object
#  83   Q15_9                  1168 non-null   object
#  84   Q15_10                 555 non-null    object
#  85   Q15_11                 319 non-null    object
#  86   Q15_12                 226 non-null    object
#  87   Q15_13                 199 non-null    object
#  88   Q15_14                 3440 non-null   object
#  89   Q15_15                 692 non-null    object
#  90   Q16                    19887 non-null  object
#  91   Q17_1                  11404 non-null  object
#  92   Q17_2                  7954 non-null   object
#  93   Q17_3                  6576 non-null   object
#  94   Q17_4                  5192 non-null   object
#  95   Q17_5                  649 non-null    object
#  96   Q17_6                  4478 non-null   object
#  97   Q17_7                  1941 non-null   object
#  98   Q17_8                  1166 non-null   object
#  99   Q17_9                  822 non-null    object
#  100  Q17_10                 548 non-null    object
#  101  Q17_11                 253 non-null    object
#  102  Q17_12                 1014 non-null   object
#  103  Q17_13                 1333 non-null   object
#  104  Q17_14                 1710 non-null   object
#  105  Q17_15                 621 non-null    object
#  106  Q18_1                  11339 non-null  object
#  107  Q18_2                  9374 non-null   object
#  108  Q18_3                  5507 non-null   object
#  109  Q18_4                  3662 non-null   object
#  110  Q18_5                  824 non-null    object
#  111  Q18_6                  3477 non-null   object
#  112  Q18_7                  6007 non-null   object
#  113  Q18_8                  1167 non-null   object
#  114  Q18_9                  3452 non-null   object
#  115  Q18_10                 2197 non-null   object
#  116  Q18_11                 1235 non-null   object
#  117  Q18_12                 1423 non-null   object
#  118  Q18_13                 1327 non-null   object
#  119  Q18_14                 539 non-null    object
#  120  Q19_1                  2294 non-null   object
#  121  Q19_2                  2496 non-null   object
#  122  Q19_3                  2526 non-null   object
#  123  Q19_4                  3665 non-null   object
#  124  Q19_5                  1344 non-null   object
#  125  Q19_6                  783 non-null    object
#  126  Q19_7                  1456 non-null   object
#  127  Q19_8                  147 non-null    object
#  128  Q20_1                  2242 non-null   object
#  129  Q20_2                  1702 non-null   object
#  130  Q20_3                  686 non-null    object
#  131  Q20_4                  2220 non-null   object
#  132  Q20_5                  1108 non-null   object
#  133  Q20_6                  127 non-null    object
#  134  Q21_1                  3088 non-null   object
#  135  Q21_2                  2013 non-null   object
#  136  Q21_3                  1794 non-null   object
#  137  Q21_4                  435 non-null    object
#  138  Q21_5                  238 non-null    object
#  139  Q21_6                  419 non-null    object
#  140  Q21_7                  631 non-null    object
#  141  Q21_8                  5423 non-null   object
#  142  Q21_9                  7123 non-null   object
#  143  Q21_10                 704 non-null    object
#  144  Q22                    3694 non-null   object
#  145  Q23                    10631 non-null  object
#  146  Q24                    9095 non-null   object
#  147  Q25                    9067 non-null   object
#  148  Q26                    8991 non-null   object
#  149  Q27                    8873 non-null   object
#  150  Q28_1                  5000 non-null   object
#  151  Q28_2                  2623 non-null   object
#  152  Q28_3                  3035 non-null   object
#  153  Q28_4                  2172 non-null   object
#  154  Q28_5                  2353 non-null   object
#  155  Q28_6                  1664 non-null   object
#  156  Q28_7                  1445 non-null   object
#  157  Q28_8                  487 non-null    object
#  158  Q29                    8137 non-null   object
#  159  Q30                    8485 non-null   object
#  160  Q31_1                  2347 non-null   object
#  161  Q31_2                  1417 non-null   object
#  162  Q31_3                  2057 non-null   object
#  163  Q31_4                  288 non-null    object
#  164  Q31_5                  231 non-null    object
#  165  Q31_6                  108 non-null    object
#  166  Q31_7                  156 non-null    object
#  167  Q31_8                  77 non-null     object
#  168  Q31_9                  57 non-null     object
#  169  Q31_10                 48 non-null     object
#  170  Q31_11                 1168 non-null   object
#  171  Q31_12                 218 non-null    object
#  172  Q32                    1930 non-null   object
#  173  Q33_1                  1610 non-null   object
#  174  Q33_2                  888 non-null    object
#  175  Q33_3                  1322 non-null   object
#  176  Q33_4                  931 non-null    object
#  177  Q33_5                  69 non-null     object
#  178  Q34_1                  616 non-null    object
#  179  Q34_2                  512 non-null    object
#  180  Q34_3                  1625 non-null   object
#  181  Q34_4                  448 non-null    object
#  182  Q34_5                  1289 non-null   object
#  183  Q34_6                  482 non-null    object
#  184  Q34_7                  772 non-null    object
#  185  Q34_8                  75 non-null     object
#  186  Q35_1                  2234 non-null   object
#  187  Q35_2                  1517 non-null   object
#  188  Q35_3                  1160 non-null   object
#  189  Q35_4                  689 non-null    object
#  190  Q35_5                  1032 non-null   object
#  191  Q35_6                  400 non-null    object
#  192  Q35_7                  193 non-null    object
#  193  Q35_8                  1204 non-null   object
#  194  Q35_9                  521 non-null    object
#  195  Q35_10                 381 non-null    object
#  196  Q35_11                 506 non-null    object
#  197  Q35_12                 357 non-null    object
#  198  Q35_13                 691 non-null    object
#  199  Q35_14                 440 non-null    object
#  200  Q35_15                 956 non-null    object
#  201  Q35_16                 218 non-null    object
#  202  Q36_1                  225 non-null    object
#  203  Q36_2                  1659 non-null   object
#  204  Q36_3                  644 non-null    object
#  205  Q36_4                  167 non-null    object
#  206  Q36_5                  1733 non-null   object
#  207  Q36_6                  208 non-null    object
#  208  Q36_7                  45 non-null     object
#  209  Q36_8                  87 non-null     object
#  210  Q36_9                  133 non-null    object
#  211  Q36_10                 39 non-null     object
#  212  Q36_11                 107 non-null    object
#  213  Q36_12                 168 non-null    object
#  214  Q36_13                 23 non-null     object
#  215  Q36_14                 2051 non-null   object
#  216  Q36_15                 192 non-null    object
#  217  Q37_1                  562 non-null    object
#  218  Q37_2                  397 non-null    object
#  219  Q37_3                  351 non-null    object
#  220  Q37_4                  124 non-null    object
#  221  Q37_5                  449 non-null    object
#  222  Q37_6                  105 non-null    object
#  223  Q37_7                  100 non-null    object
#  224  Q37_8                  114 non-null    object
#  225  Q37_9                  31 non-null     object
#  226  Q37_10                 53 non-null     object
#  227  Q37_11                 115 non-null    object
#  228  Q37_12                 3017 non-null   object
#  229  Q37_13                 122 non-null    object
#  230  Q38_1                  464 non-null    object
#  231  Q38_2                  123 non-null    object
#  232  Q38_3                  194 non-null    object
#  233  Q38_4                  126 non-null    object
#  234  Q38_5                  262 non-null    object
#  235  Q38_6                  324 non-null    object
#  236  Q38_7                  3537 non-null   object
#  237  Q38_8                  128 non-null    object
#  238  Q39_1                  523 non-null    object
#  239  Q39_2                  168 non-null    object
#  240  Q39_3                  225 non-null    object
#  241  Q39_4                  71 non-null     object
#  242  Q39_5                  94 non-null     object
#  243  Q39_6                  64 non-null     object
#  244  Q39_7                  54 non-null     object
#  245  Q39_8                  63 non-null     object
#  246  Q39_9                  48 non-null     object
#  247  Q39_10                 622 non-null    object
#  248  Q39_11                 3321 non-null   object
#  249  Q39_12                 130 non-null    object
#  250  Q40_1                  129 non-null    object
#  251  Q40_2                  382 non-null    object
#  252  Q40_3                  57 non-null     object
#  253  Q40_4                  856 non-null    object
#  254  Q40_5                  36 non-null     object
#  255  Q40_6                  74 non-null     object
#  256  Q40_7                  660 non-null    object
#  257  Q40_8                  25 non-null     object
#  258  Q40_9                  53 non-null     object
#  259  Q40_10                 40 non-null     object
#  260  Q40_11                 33 non-null     object
#  261  Q40_12                 66 non-null     object
#  262  Q40_13                 144 non-null    object
#  263  Q40_14                 2931 non-null   object
#  264  Q40_15                 125 non-null    object
#  265  Q41_1                  290 non-null    object
#  266  Q41_2                  207 non-null    object
#  267  Q41_3                  129 non-null    object
#  268  Q41_4                  185 non-null    object
#  269  Q41_5                  81 non-null     object
#  270  Q41_6                  70 non-null     object
#  271  Q41_7                  37 non-null     object
#  272  Q41_8                  3921 non-null   object
#  273  Q41_9                  97 non-null     object
#  274  Q42_1                  2683 non-null   object
#  275  Q42_2                  654 non-null    object
#  276  Q42_3                  68 non-null     object
#  277  Q42_4                  59 non-null     object
#  278  Q42_5                  27 non-null     object
#  279  Q42_6                  40 non-null     object
#  280  Q42_7                  59 non-null     object
#  281  Q42_8                  1773 non-null   object
#  282  Q42_9                  71 non-null     object
#  283  Q43                    4594 non-null   object
#  284  Q44_1                  3996 non-null   object
#  285  Q44_2                  3788 non-null   object
#  286  Q44_3                  2679 non-null   object
#  287  Q44_4                  11182 non-null  object
#  288  Q44_5                  4007 non-null   object
#  289  Q44_6                  11958 non-null  object
#  290  Q44_7                  2121 non-null   object
#  291  Q44_8                  7767 non-null   object
#  292  Q44_9                  3805 non-null   object
#  293  Q44_10                 1727 non-null   object
#  294  Q44_11                 1269 non-null   object
#  295  Q44_12                 836 non-null    object
# dtypes: object(296)
# memory usage: 54.2+ MB

# %%
# percentage of missing values
df.isnull().sum() / df.shape[0] * 100
# Out:
# Duration (in seconds)     0.000000
# Q2                        0.000000
# Q3                        0.000000
# Q4                        0.000000
# Q5                        0.000000
#                            ...
# Q44_8                    67.634803
# Q44_9                    84.144512
# Q44_10                   92.803567
# Q44_11                   94.712059
# Q44_12                   96.516376
# Length: 296, dtype: float64

# %%
#getting statistics of data
df.describe().T
# Out:
#                        count unique  \
# Duration (in seconds)  23998   4329
# Q2                     23998     12
# Q3                     23998      6
# Q4                     23998     59
# Q5                     23998      3
# ...                      ...    ...
# Q44_8                   7767      2
# Q44_9                   3805      2
# Q44_10                  1727      2
# Q44_11                  1269      2
# Q44_12                   836      2
#
#                                                                      top  \
# Duration (in seconds)                                                230
# Q2                                                                 18-21
# Q3                                                                   Man
# Q4                                                                 India
# Q5                                                                    No
# ...                                                                  ...
# Q44_8                  Blogs (Towards Data Science, Analytics Vidhya,...
# Q44_9                  Journal Publications (peer-reviewed journals, ...
# Q44_10                      Slack Communities (ods.ai, kagglenoobs, etc)
# Q44_11                                                              None
# Q44_12                                                             Other
#
#                         freq
# Duration (in seconds)     59
# Q2                      4559
# Q3                     18266
# Q4                      8792
# Q5                     12036
# ...                      ...
# Q44_8                   7766
# Q44_9                   3804
# Q44_10                  1726
# Q44_11                  1268
# Q44_12                   835
#
# [296 rows x 4 columns]

# %%
st.write("Analyzing data on women in universities")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-0f6a39ffb9d4> in <cell line: 1>()
# ----> 1 st.write("Analyzing data on women in universities")
#
# NameError: name 'st' is not defined

# %% [markdown]
# # New Section
